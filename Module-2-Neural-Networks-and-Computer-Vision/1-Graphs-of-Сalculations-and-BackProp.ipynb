# %% [markdown]
# # Графы вычислений и BackProp

# %% [markdown]
# **Задание 1.**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Задание 2.**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Задание 3.**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Задание 4.**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Задание 5.**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Задание 6.**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Задание 7.**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Задание 8.**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Задание 9.**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Задание 10.**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Решение задач 8, 9 и 10.**

# %% [markdown]
# ![image.png](attachment:image.png)
